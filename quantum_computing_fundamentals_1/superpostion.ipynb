# %%
# !pip3 install qiskit
# !pip3 install numpy
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4,'9')
creg_c = ClassicalRegister(3,'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])

circuit.draw('text')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in /Users/student/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (5.5.0)
# Requirement already satisfied: typing-extensions in /Users/student/Library/Python/3.9/lib/python/site-packages (from qiskit) (4.15.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/student/Library/Python/3.9/lib/python/site-packages (2.0.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
#      ┌───┐┌─┐
# 9_0: ┤ H ├┤M├
#      └───┘└╥┘
# 9_1: ──────╫─
#            ║
# 9_2: ──────╫─
#            ║
# 9_3: ──────╫─
#            ║
# c: 3/══════╩═
#            0
